# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from PIL import Image
import os
import math

# %%
year = 2002

cme = pickle.load(open(f"cme_{year}.pkl", "rb"))
hproton = pickle.load(open(f"hproton_{year}.pkl", "rb"))

len(cme) == len(hproton)
# Out:
# True

# %%
plt.plot(cme/np.max(cme))
plt.plot(hproton/np.max(hproton))

# %%
plt.plot(cme)

# %%
plt.plot(hproton)
