# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from PIL import Image
import os

# %%
import pandas as pd

hproton = pd.read_csv(
    "./hproton_data/2000_DPD.txt",
    delim_whitespace=True,
    comment="#",
    header=None,
    names=[
        "year", "month", "day",
        "p_gt_1MeV", "p_gt_10MeV", "p_gt_100MeV",
        "e_gt_0p6MeV", "e_gt_2MeV",
        "neutron_pct"
    ]
)

hproton.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_37168\337644530.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   hproton = pd.read_csv(
#         year  month       day p_gt_1MeV    p_gt_10MeV  p_gt_100MeV  \
# 0  :Product:  Daily  Particle      Data  2000_DPD.txt          NaN
# 1       2000     01        01   5.9e+06       1.6e+04       2800.0
# 2       2000     01        02   2.1e+06       1.4e+04       2900.0
# 3       2000     01        03   9.0e+05       1.4e+04       2900.0
# 4       2000     01        04   4.4e+05       1.2e+04       2700.0
#
#     e_gt_0p6MeV    e_gt_2MeV  neutron_pct
# 0           NaN          NaN          NaN
# 1  2.900000e+10  130000000.0      -999.99
# 2  3.400000e+10  170000000.0        12.39
# 3  3.900000e+10  270000000.0         4.72
# 4  3.100000e+10  230000000.0         4.49

# %%
# hproton_oct = hproton[hproton["month"].isin(['06', '07', '08', '09', '10', '11', '12'])].copy()
# hproton_oct

# %%
hproton_oct_100MeV = hproton["p_gt_100MeV"].copy().astype(float)
hproton_oct_100MeV.head()
# Out:
# 0       NaN
# 1    2800.0
# 2    2900.0
# 3    2900.0
# 4    2700.0
# Name: p_gt_100MeV, dtype: float64

# %%
hproton_oct_100MeV.plot()
# Out:
# <Axes: >

# %%
hproton_oct_100MeV[hproton_oct_100MeV > 200000]
# Out:
# 196    11000000.0
# 197     4700000.0
# 314    13000000.0
# 315      420000.0
# Name: p_gt_100MeV, dtype: float64

# %%
hproton_oct_100MeV[hproton_oct_100MeV < 10**5].plot()
# Out:
# <Axes: >

# %%
hproton_oct_100MeV[hproton_oct_100MeV < 10**4][hproton_oct_100MeV > 0].plot()
# Out:
# <Axes: >

# %%
pickle.dump(hproton_oct_100MeV.values, open("hproton_100MeV.pkl", "wb"))
